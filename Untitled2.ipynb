# %%
import numpy as np
from skimage import color

# import torchvision.transforms as transforms
from torchvision import transforms
from torch.utils.data import DataLoader
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
num_epochs = 1000
batch_size = 512
learning_rate = 1e-3
use_gpu = True

# %%
#https://colab.research.google.com/github/smartgeometry-ucl/dl4g/blob/master/colorization.ipynb#scrollTo=j2MERVvtGYEy
#https://colab.research.google.com/drive/1r45y6bnxT1d8qUe5YDovWYUbfX1hMnAz#scrollTo=rRoQxRmuWqnG not using right now
class ColorNet(nn.Module):
    def __init__(self, d=128):
        super(ColorNet, self).__init__()
        
        self.conv1 = nn.Conv2d(1, 32, kernel_size=4, stride=2, padding=1) # out: 32 x 16 x 16
        self.conv1_bn = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=1) # out: 64 x 8 x 8
        self.conv2_bn = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1) # out: 128 x 4 x 4
        self.conv3_bn = nn.BatchNorm2d(128)
        self.conv4 = nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1) # out: 128 x 4 x 4
        self.conv4_bn = nn.BatchNorm2d(128)
        self.conv5 = nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1) # out: 128 x 4 x 4
        self.conv5_bn = nn.BatchNorm2d(128)
        self.conv6 = nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1) # out: 128 x 4 x 4
        self.conv6_bn = nn.BatchNorm2d(128)
        self.tconv1 = nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1) # out: 64 x 8 x 8
        self.tconv1_bn = nn.BatchNorm2d(64)
        self.tconv2 = nn.ConvTranspose2d(64, 32, kernel_size=4, stride=2, padding=1) # out: 32 x 16 x 16
        self.tconv2_bn = nn.BatchNorm2d(32)
        self.tconv3 = nn.ConvTranspose2d(32, 2, kernel_size=4, stride=2, padding=1) # out: 2 x 32 x 32

    def forward(self, input):
        x = F.relu(self.conv1_bn(self.conv1(input)))
        x = F.relu(self.conv2_bn(self.conv2(x)))
        x = F.relu(self.conv3_bn(self.conv3(x)))
        x = F.relu(self.conv4_bn(self.conv4(x)))
        x = F.relu(self.conv5_bn(self.conv5(x)))
        x = F.relu(self.conv6_bn(self.conv6(x)))
        x = F.relu(self.tconv1_bn(self.tconv1(x)))
        x = F.relu(self.tconv2_bn(self.tconv2(x)))
        x = self.tconv3(x)

        return x

cnet = ColorNet()

device = torch.device("cuda:0" if use_gpu and torch.cuda.is_available() else "cpu")
cnet = cnet.to(device)

num_params = sum(p.numel() for p in cnet.parameters() if p.requires_grad)
print('Number of parameters: %d' % (num_params))
# Out:
# Number of parameters: 773698

# %%
def import_image(img):
    return torch.FloatTensor(np.transpose(color.rgb2lab(np.array(img)), (2, 0, 1)))

img_transform = transforms.Compose([
    transforms.Lambda(import_image)
])


train_transforms = transforms.Compose([
                                transforms.RandomApply(torch.nn.ModuleList([
                                transforms.RandomRotation(30),
                                transforms.RandomResizedCrop(224),
                                transforms.RandomHorizontalFlip(),
                                #transforms.Grayscale(num_output_channels=1),
                                #transforms.Grayscale(num_output_channels=3),
                                
                                ]), p=0.3),
                                transforms.RandomGrayscale(p=0.1),
                                transforms.RandomRotation(30),
                                transforms.RandomVerticalFlip(p=0.5),
                                transforms.RandomResizedCrop(224),
                                transforms.RandomHorizontalFlip(),
                                #transforms.Lambda(color.rgb2lab),
                                #transforms.ToTensor(),
                                transforms.Normalize([0, 0, 0], [1, 1, 1]),
                                transforms.RandomApply(torch.nn.ModuleList([     
                                    transforms.Normalize([0, 0, 0], [1, 1, 1]),
                                    transforms.Normalize([0.5, 0.5, 0.5], [0.01, 0.01, 0.01]),
                                    transforms.Normalize([0.8, 0.8, 0.8], [0.2, 0.2, 0.2]),
                                ])),
                                transforms.Lambda(import_image)
                           
])



test_transform = transforms.Compose([
        transforms.Lambda(color.rgb2lab),
        transforms.ToTensor()
    ])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-377a447de76c> in <module>
#       8
#       9 train_transforms = transforms.Compose([
# ---> 10                                 transforms.RandomApply(torch.nn.ModuleList([
#      11                                 transforms.RandomRotation(30),
#      12                                 transforms.RandomResizedCrop(224),
#
# /usr/lib/python3/dist-packages/torch/nn/modules/container.py in __init__(self, modules)
#     146         super(ModuleList, self).__init__()
#     147         if modules is not None:
# --> 148             self += modules
#     149
#     150     def _get_abs_string_index(self, idx):
#
# /usr/lib/python3/dist-packages/torch/nn/modules/container.py in __iadd__(self, modules)
#     187
#     188     def __iadd__(self: T, modules: Iterable[Module]) -> T:
# --> 189         return self.extend(modules)
#     190
#     191     @_copy_to_script_wrapper
#
# /usr/lib/python3/dist-packages/torch/nn/modules/container.py in extend(self, modules)
#     226         offset = len(self)
#     227         for i, module in enumerate(modules):
# --> 228             self.add_module(str(offset + i), module)
#     229         return self
#     230
#
# /usr/lib/python3/dist-packages/torch/nn/modules/module.py in add_module(self, name, module)
#     337         """
#     338         if not isinstance(module, Module) and module is not None:
# --> 339             raise TypeError("{} is not a Module subclass".format(
#     340                 torch.typename(module)))
#     341         elif not isinstance(name, torch._six.string_classes):
#
# TypeError: torchvision.transforms.transforms.RandomRotation is not a Module subclass

# %%
from torchvision import datasets, transforms

#dataset_notransform = datasets.ImageFolder("face_image_testset/", transform = test_transform)

dataset_notransform = datasets.ImageFolder("face_image_testset/", transform = img_transform)

train_dataloader = torch.utils.data.DataLoader(dataset_notransform,            
                                          batch_size=batch_size, 
                                          #GPU_data = True,
                                          pin_memory = True,
                                          num_workers=1,
                                         
                                         )


# train_dataloader = torch.utils.data.DataLoader(data_set_train_tensor_lab,            
#                                           batch_size=32, 
#                                           #GPU_data = True,
#                                           pin_memory = True,
#                                           num_workers=1,
                                         
#                                          )

# %%
import cv2
import torch
import numpy as np
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
from PIL import Image
# %matplotlib inline
data_iter = iter(train_dataloader)
data_iter

# %%
optimizer = torch.optim.Adam(params=cnet.parameters(), lr=learning_rate)

# set to training mode
cnet.train()

train_loss_avg = []

print('Training ...')
for epoch in range(num_epochs):
    train_loss_avg.append(0)
    num_batches = 0
    
    for lab_batch, _ in train_dataloader:
        
        lab_batch = lab_batch.to(device)
        
        # apply the color net to the luminance component of the Lab images
        # to get the color (ab) components
        predicted_ab_batch = cnet(lab_batch[:, 0:1, :, :])
        
        # loss is the L2 error to the actual color (ab) components
        loss = F.mse_loss(predicted_ab_batch, lab_batch[:, 1:3, :, :])
        
        # backpropagation
        optimizer.zero_grad()
        loss.backward()
        
        # one step of the optmizer (using the gradients from backpropagation)
        optimizer.step()
        
        train_loss_avg[-1] += loss.item()
        num_batches += 1
        
    train_loss_avg[-1] /= num_batches
    print('Epoch [%d / %d] average reconstruction error: %f' % (epoch+1, num_epochs, train_loss_avg[-1]))
# Out:
# Training ...
# Epoch [1 / 1000] average reconstruction error: 171.294006
# Epoch [2 / 1000] average reconstruction error: 168.707581
# Epoch [3 / 1000] average reconstruction error: 164.994019
# Epoch [4 / 1000] average reconstruction error: 162.055008
# Epoch [5 / 1000] average reconstruction error: 159.845139
# Epoch [6 / 1000] average reconstruction error: 157.655960
# Epoch [7 / 1000] average reconstruction error: 155.875183
# Epoch [8 / 1000] average reconstruction error: 154.195450
# Epoch [9 / 1000] average reconstruction error: 152.804169
# Epoch [10 / 1000] average reconstruction error: 151.272659
# Epoch [11 / 1000] average reconstruction error: 149.911896
# Epoch [12 / 1000] average reconstruction error: 148.537888
# Epoch [13 / 1000] average reconstruction error: 147.147369
# Epoch [14 / 1000] average reconstruction error: 145.795578
# Epoch [15 / 1000] average reconstruction error: 144.425812
# Epoch [16 / 1000] average reconstruction error: 143.053772
# Epoch [17 / 1000] average reconstruction error: 141.672379
# Epoch [18 / 1000] average reconstruction error: 140.281174
# Epoch [19 / 1000] average reconstruction error: 138.858078
# Epoch [20 / 1000] average reconstruction error: 137.434601
# Epoch [21 / 1000] average reconstruction error: 136.000656
# Epoch [22 / 1000] average reconstruction error: 134.574646
# Epoch [23 / 1000] average reconstruction error: 133.186768
# Epoch [24 / 1000] average reconstruction error: 131.703323
# Epoch [25 / 1000] average reconstruction error: 130.202560
# Epoch [26 / 1000] average reconstruction error: 128.760635
# Epoch [27 / 1000] average reconstruction error: 127.369926
# Epoch [28 / 1000] average reconstruction error: 126.187309
# Epoch [29 / 1000] average reconstruction error: 124.455551
# Epoch [30 / 1000] average reconstruction error: 123.082138
# Epoch [31 / 1000] average reconstruction error: 121.576302
# Epoch [32 / 1000] average reconstruction error: 120.110527
# Epoch [33 / 1000] average reconstruction error: 118.629585
# Epoch [34 / 1000] average reconstruction error: 117.051353
# Epoch [35 / 1000] average reconstruction error: 115.709702
# Epoch [36 / 1000] average reconstruction error: 114.197128
# Epoch [37 / 1000] average reconstruction error: 112.827713
# Epoch [38 / 1000] average reconstruction error: 111.415955
# Epoch [39 / 1000] average reconstruction error: 109.842766
# Epoch [40 / 1000] average reconstruction error: 108.387726
# Epoch [41 / 1000] average reconstruction error: 106.793434
# Epoch [42 / 1000] average reconstruction error: 105.406532
# Epoch [43 / 1000] average reconstruction error: 103.822525
# Epoch [44 / 1000] average reconstruction error: 102.539536
# Epoch [45 / 1000] average reconstruction error: 100.985168
# Epoch [46 / 1000] average reconstruction error: 99.678986
# Epoch [47 / 1000] average reconstruction error: 98.076263
# Epoch [48 / 1000] average reconstruction error: 96.649673
# Epoch [49 / 1000] average reconstruction error: 95.265305
# Epoch [50 / 1000] average reconstruction error: 94.067093
# Epoch [51 / 1000] average reconstruction error: 92.893272
# Epoch [52 / 1000] average reconstruction error: 91.029999
# Epoch [53 / 1000] average reconstruction error: 89.904831
# Epoch [54 / 1000] average reconstruction error: 88.323105
# Epoch [55 / 1000] average reconstruction error: 86.976524
# Epoch [56 / 1000] average reconstruction error: 85.500748
# Epoch [57 / 1000] average reconstruction error: 84.220169
# Epoch [58 / 1000] average reconstruction error: 82.805504
# Epoch [59 / 1000] average reconstruction error: 81.389496
# Epoch [60 / 1000] average reconstruction error: 80.109741
# Epoch [61 / 1000] average reconstruction error: 78.606392
# Epoch [62 / 1000] average reconstruction error: 77.226494
# Epoch [63 / 1000] average reconstruction error: 75.940147
# Epoch [64 / 1000] average reconstruction error: 74.646194
# Epoch [65 / 1000] average reconstruction error: 73.454079
# Epoch [66 / 1000] average reconstruction error: 72.064613
# Epoch [67 / 1000] average reconstruction error: 70.694389
# Epoch [68 / 1000] average reconstruction error: 69.269402
# Epoch [69 / 1000] average reconstruction error: 68.060356
# Epoch [70 / 1000] average reconstruction error: 66.941368
# Epoch [71 / 1000] average reconstruction error: 66.289223
# Epoch [72 / 1000] average reconstruction error: 64.532631
# Epoch [73 / 1000] average reconstruction error: 63.280510
# Epoch [74 / 1000] average reconstruction error: 62.134274
# Epoch [75 / 1000] average reconstruction error: 60.716381
# Epoch [76 / 1000] average reconstruction error: 59.564518
# Epoch [77 / 1000] average reconstruction error: 58.361549
# Epoch [78 / 1000] average reconstruction error: 57.199547
# Epoch [79 / 1000] average reconstruction error: 55.999638
# Epoch [80 / 1000] average reconstruction error: 54.817619
# Epoch [81 / 1000] average reconstruction error: 53.666679
# Epoch [82 / 1000] average reconstruction error: 52.599815
# Epoch [83 / 1000] average reconstruction error: 51.484097
# Epoch [84 / 1000] average reconstruction error: 50.361851
# Epoch [85 / 1000] average reconstruction error: 49.288738
# Epoch [86 / 1000] average reconstruction error: 48.253567
# Epoch [87 / 1000] average reconstruction error: 47.195953
# Epoch [88 / 1000] average reconstruction error: 46.171608
# Epoch [89 / 1000] average reconstruction error: 45.196556
# Epoch [90 / 1000] average reconstruction error: 44.207573
# Epoch [91 / 1000] average reconstruction error: 43.244766
# Epoch [92 / 1000] average reconstruction error: 42.291752
# Epoch [93 / 1000] average reconstruction error: 41.408066
# Epoch [94 / 1000] average reconstruction error: 40.543255
# Epoch [95 / 1000] average reconstruction error: 39.748238
# Epoch [96 / 1000] average reconstruction error: 39.136551
# Epoch [97 / 1000] average reconstruction error: 39.004967
# Epoch [98 / 1000] average reconstruction error: 37.326145
# Epoch [99 / 1000] average reconstruction error: 36.897903
# Epoch [100 / 1000] average reconstruction error: 35.875679
# Epoch [101 / 1000] average reconstruction error: 35.118935
# Epoch [102 / 1000] average reconstruction error: 34.356152
# Epoch [103 / 1000] average reconstruction error: 33.658009
# Epoch [104 / 1000] average reconstruction error: 32.816498
# Epoch [105 / 1000] average reconstruction error: 32.049049
# Epoch [106 / 1000] average reconstruction error: 31.393845
# Epoch [107 / 1000] average reconstruction error: 30.561144
# Epoch [108 / 1000] average reconstruction error: 29.958849
# Epoch [109 / 1000] average reconstruction error: 29.201147
# Epoch [110 / 1000] average reconstruction error: 28.573803
# Epoch [111 / 1000] average reconstruction error: 27.945547
# Epoch [112 / 1000] average reconstruction error: 27.288986
# Epoch [113 / 1000] average reconstruction error: 26.692921
# Epoch [114 / 1000] average reconstruction error: 26.104912
# Epoch [115 / 1000] average reconstruction error: 25.499819
# Epoch [116 / 1000] average reconstruction error: 24.967442
# Epoch [117 / 1000] average reconstruction error: 24.377289
# Epoch [118 / 1000] average reconstruction error: 23.867886
# Epoch [119 / 1000] average reconstruction error: 23.352545
# Epoch [120 / 1000] average reconstruction error: 22.817474
# Epoch [121 / 1000] average reconstruction error: 22.389103
# Epoch [122 / 1000] average reconstruction error: 21.958735
# Epoch [123 / 1000] average reconstruction error: 21.613724
# Epoch [124 / 1000] average reconstruction error: 21.194668
# Epoch [125 / 1000] average reconstruction error: 20.643906
# Epoch [126 / 1000] average reconstruction error: 20.167885
# Epoch [127 / 1000] average reconstruction error: 19.899725
# Epoch [128 / 1000] average reconstruction error: 19.408405
# Epoch [129 / 1000] average reconstruction error: 19.055172
# Epoch [130 / 1000] average reconstruction error: 18.747202
# Epoch [131 / 1000] average reconstruction error: 18.395662
# Epoch [132 / 1000] average reconstruction error: 17.987274
# Epoch [133 / 1000] average reconstruction error: 17.474140
# Epoch [134 / 1000] average reconstruction error: 17.181429
# Epoch [135 / 1000] average reconstruction error: 16.840286
# Epoch [136 / 1000] average reconstruction error: 16.474710
# Epoch [137 / 1000] average reconstruction error: 16.117643
# Epoch [138 / 1000] average reconstruction error: 15.843010
# Epoch [139 / 1000] average reconstruction error: 15.528288
# Epoch [140 / 1000] average reconstruction error: 15.202512
# Epoch [141 / 1000] average reconstruction error: 14.934711
# Epoch [142 / 1000] average reconstruction error: 14.661499
# Epoch [143 / 1000] average reconstruction error: 14.376368
# Epoch [144 / 1000] average reconstruction error: 14.096889
# Epoch [145 / 1000] average reconstruction error: 13.849844
# Epoch [146 / 1000] average reconstruction error: 13.612430
# Epoch [147 / 1000] average reconstruction error: 13.356872
# Epoch [148 / 1000] average reconstruction error: 13.122458
# Epoch [149 / 1000] average reconstruction error: 12.903575
# Epoch [150 / 1000] average reconstruction error: 12.684789
# Epoch [151 / 1000] average reconstruction error: 12.504235
# Epoch [152 / 1000] average reconstruction error: 12.323533
# Epoch [153 / 1000] average reconstruction error: 12.256669
# Epoch [154 / 1000] average reconstruction error: 12.045737
# Epoch [155 / 1000] average reconstruction error: 11.794779
# Epoch [156 / 1000] average reconstruction error: 11.567083
# Epoch [157 / 1000] average reconstruction error: 11.442410
# Epoch [158 / 1000] average reconstruction error: 11.302415
# Epoch [159 / 1000] average reconstruction error: 10.974929
# Epoch [160 / 1000] average reconstruction error: 10.963173
# Epoch [161 / 1000] average reconstruction error: 10.809038
# Epoch [162 / 1000] average reconstruction error: 10.607032
# Epoch [163 / 1000] average reconstruction error: 10.534974
# Epoch [164 / 1000] average reconstruction error: 10.570860
# Epoch [165 / 1000] average reconstruction error: 10.813793
# Epoch [166 / 1000] average reconstruction error: 10.975394
# Epoch [167 / 1000] average reconstruction error: 10.393347
# Epoch [168 / 1000] average reconstruction error: 10.345314
# Epoch [169 / 1000] average reconstruction error: 10.235487
# Epoch [170 / 1000] average reconstruction error: 10.038679
# Epoch [171 / 1000] average reconstruction error: 9.753573
# Epoch [172 / 1000] average reconstruction error: 9.622450
# Epoch [173 / 1000] average reconstruction error: 9.581248
# Epoch [174 / 1000] average reconstruction error: 9.375232
# Epoch [175 / 1000] average reconstruction error: 9.201418
# Epoch [176 / 1000] average reconstruction error: 8.967777
# Epoch [177 / 1000] average reconstruction error: 8.893846
# Epoch [178 / 1000] average reconstruction error: 8.735223
# Epoch [179 / 1000] average reconstruction error: 8.551396
# Epoch [180 / 1000] average reconstruction error: 8.429593
# Epoch [181 / 1000] average reconstruction error: 8.320310
# Epoch [182 / 1000] average reconstruction error: 8.161381
# Epoch [183 / 1000] average reconstruction error: 8.089776
# Epoch [184 / 1000] average reconstruction error: 7.945472
# Epoch [185 / 1000] average reconstruction error: 7.820151
# Epoch [186 / 1000] average reconstruction error: 7.728363
# Epoch [187 / 1000] average reconstruction error: 7.618443
# Epoch [188 / 1000] average reconstruction error: 7.482412
# Epoch [189 / 1000] average reconstruction error: 7.399439
# Epoch [190 / 1000] average reconstruction error: 7.284020
# Epoch [191 / 1000] average reconstruction error: 7.173070
# Epoch [192 / 1000] average reconstruction error: 7.070913
# Epoch [193 / 1000] average reconstruction error: 6.967281
# Epoch [194 / 1000] average reconstruction error: 6.877638
# Epoch [195 / 1000] average reconstruction error: 6.780313
# Epoch [196 / 1000] average reconstruction error: 6.710841
# Epoch [197 / 1000] average reconstruction error: 6.619627
# Epoch [198 / 1000] average reconstruction error: 6.564614
# Epoch [199 / 1000] average reconstruction error: 6.544509
# Epoch [200 / 1000] average reconstruction error: 6.664484
# Epoch [201 / 1000] average reconstruction error: 6.504617
# Epoch [202 / 1000] average reconstruction error: 6.287521
# Epoch [203 / 1000] average reconstruction error: 6.259594
# Epoch [204 / 1000] average reconstruction error: 6.190495
# Epoch [205 / 1000] average reconstruction error: 6.059490
# Epoch [206 / 1000] average reconstruction error: 6.008381
# Epoch [207 / 1000] average reconstruction error: 5.943478
# Epoch [208 / 1000] average reconstruction error: 5.823096
# Epoch [209 / 1000] average reconstruction error: 5.762730
# Epoch [210 / 1000] average reconstruction error: 5.701902
# Epoch [211 / 1000] average reconstruction error: 5.606040
# Epoch [212 / 1000] average reconstruction error: 5.534142
# Epoch [213 / 1000] average reconstruction error: 5.479021
# Epoch [214 / 1000] average reconstruction error: 5.408332
# Epoch [215 / 1000] average reconstruction error: 5.337660
# Epoch [216 / 1000] average reconstruction error: 5.290629
# Epoch [217 / 1000] average reconstruction error: 5.262731
# Epoch [218 / 1000] average reconstruction error: 5.241204
# Epoch [219 / 1000] average reconstruction error: 5.244421
# Epoch [220 / 1000] average reconstruction error: 5.319903
# Epoch [221 / 1000] average reconstruction error: 5.356126
# Epoch [222 / 1000] average reconstruction error: 5.227847
# Epoch [223 / 1000] average reconstruction error: 5.073523
# Epoch [224 / 1000] average reconstruction error: 5.084437
# Epoch [225 / 1000] average reconstruction error: 5.039125
# Epoch [226 / 1000] average reconstruction error: 4.827407
# Epoch [227 / 1000] average reconstruction error: 4.830128
# Epoch [228 / 1000] average reconstruction error: 4.771249
# Epoch [229 / 1000] average reconstruction error: 4.699088
# Epoch [230 / 1000] average reconstruction error: 4.613713
# Epoch [231 / 1000] average reconstruction error: 4.568082
# Epoch [232 / 1000] average reconstruction error: 4.496555
# Epoch [233 / 1000] average reconstruction error: 4.421158
# Epoch [234 / 1000] average reconstruction error: 4.406686
# Epoch [235 / 1000] average reconstruction error: 4.348703
# Epoch [236 / 1000] average reconstruction error: 4.383062
# Epoch [237 / 1000] average reconstruction error: 4.542459
# Epoch [238 / 1000] average reconstruction error: 4.334560
# Epoch [239 / 1000] average reconstruction error: 4.305029
# Epoch [240 / 1000] average reconstruction error: 4.380421
# Epoch [241 / 1000] average reconstruction error: 4.238313
# Epoch [242 / 1000] average reconstruction error: 4.160481
# Epoch [243 / 1000] average reconstruction error: 4.114105
# Epoch [244 / 1000] average reconstruction error: 4.046200
# Epoch [245 / 1000] average reconstruction error: 3.973379
# Epoch [246 / 1000] average reconstruction error: 3.933229
# Epoch [247 / 1000] average reconstruction error: 3.863368
# Epoch [248 / 1000] average reconstruction error: 3.817820
# Epoch [249 / 1000] average reconstruction error: 3.756755
# Epoch [250 / 1000] average reconstruction error: 3.717439
# Epoch [251 / 1000] average reconstruction error: 3.657620
# Epoch [252 / 1000] average reconstruction error: 3.621734
# Epoch [253 / 1000] average reconstruction error: 3.566652
# Epoch [254 / 1000] average reconstruction error: 3.534057
# Epoch [255 / 1000] average reconstruction error: 3.483289
# Epoch [256 / 1000] average reconstruction error: 3.448836
# Epoch [257 / 1000] average reconstruction error: 3.404175
# Epoch [258 / 1000] average reconstruction error: 3.378998
# Epoch [259 / 1000] average reconstruction error: 3.337296
# Epoch [260 / 1000] average reconstruction error: 3.327555
# Epoch [261 / 1000] average reconstruction error: 3.347156
# Epoch [262 / 1000] average reconstruction error: 3.427521
# Epoch [263 / 1000] average reconstruction error: 3.685024
# Epoch [264 / 1000] average reconstruction error: 3.509447
# Epoch [265 / 1000] average reconstruction error: 3.407394
# Epoch [266 / 1000] average reconstruction error: 3.306423
# Epoch [267 / 1000] average reconstruction error: 3.337097
# Epoch [268 / 1000] average reconstruction error: 3.355654
# Epoch [269 / 1000] average reconstruction error: 3.329746
# Epoch [270 / 1000] average reconstruction error: 3.350013
# Epoch [271 / 1000] average reconstruction error: 3.177632
# Epoch [272 / 1000] average reconstruction error: 3.147916
# Epoch [273 / 1000] average reconstruction error: 3.123258
# Epoch [274 / 1000] average reconstruction error: 3.099569
# Epoch [275 / 1000] average reconstruction error: 2.998627
# Epoch [276 / 1000] average reconstruction error: 2.975949
# Epoch [277 / 1000] average reconstruction error: 2.953145
# Epoch [278 / 1000] average reconstruction error: 2.904094
# Epoch [279 / 1000] average reconstruction error: 2.885389
# Epoch [280 / 1000] average reconstruction error: 2.841346
# Epoch [281 / 1000] average reconstruction error: 2.811170
# Epoch [282 / 1000] average reconstruction error: 2.788204
# Epoch [283 / 1000] average reconstruction error: 2.750992
# Epoch [284 / 1000] average reconstruction error: 2.726539
# Epoch [285 / 1000] average reconstruction error: 2.701017
# Epoch [286 / 1000] average reconstruction error: 2.658462
# Epoch [287 / 1000] average reconstruction error: 2.636829
# Epoch [288 / 1000] average reconstruction error: 2.609573
# Epoch [289 / 1000] average reconstruction error: 2.577991
# Epoch [290 / 1000] average reconstruction error: 2.559901
# Epoch [291 / 1000] average reconstruction error: 2.556753
# Epoch [292 / 1000] average reconstruction error: 2.582909
# Epoch [293 / 1000] average reconstruction error: 2.588148
# Epoch [294 / 1000] average reconstruction error: 2.574328
# Epoch [295 / 1000] average reconstruction error: 2.534306
# Epoch [296 / 1000] average reconstruction error: 2.499971
# Epoch [297 / 1000] average reconstruction error: 2.522962
# Epoch [298 / 1000] average reconstruction error: 2.524253
# Epoch [299 / 1000] average reconstruction error: 2.495523
# Epoch [300 / 1000] average reconstruction error: 2.481781
# Epoch [301 / 1000] average reconstruction error: 2.466892
# Epoch [302 / 1000] average reconstruction error: 2.401608
# Epoch [303 / 1000] average reconstruction error: 2.384512
# Epoch [304 / 1000] average reconstruction error: 2.387691
# Epoch [305 / 1000] average reconstruction error: 2.327854
# Epoch [306 / 1000] average reconstruction error: 2.318768
# Epoch [307 / 1000] average reconstruction error: 2.270827
# Epoch [308 / 1000] average reconstruction error: 2.259382
# Epoch [309 / 1000] average reconstruction error: 2.254420
# Epoch [310 / 1000] average reconstruction error: 2.222749
# Epoch [311 / 1000] average reconstruction error: 2.189375
# Epoch [312 / 1000] average reconstruction error: 2.186234
# Epoch [313 / 1000] average reconstruction error: 2.163438
# Epoch [314 / 1000] average reconstruction error: 2.135373
# Epoch [315 / 1000] average reconstruction error: 2.119349
# Epoch [316 / 1000] average reconstruction error: 2.103625
# Epoch [317 / 1000] average reconstruction error: 2.082912
# Epoch [318 / 1000] average reconstruction error: 2.077711
# Epoch [319 / 1000] average reconstruction error: 2.065007
# Epoch [320 / 1000] average reconstruction error: 2.048411
# Epoch [321 / 1000] average reconstruction error: 2.050978
# Epoch [322 / 1000] average reconstruction error: 2.067689
# Epoch [323 / 1000] average reconstruction error: 2.097653
# Epoch [324 / 1000] average reconstruction error: 2.206702
# Epoch [325 / 1000] average reconstruction error: 2.282999
# Epoch [326 / 1000] average reconstruction error: 2.246951
# Epoch [327 / 1000] average reconstruction error: 2.190984
# Epoch [328 / 1000] average reconstruction error: 2.243546
# Epoch [329 / 1000] average reconstruction error: 2.243889
# Epoch [330 / 1000] average reconstruction error: 2.110570
# Epoch [331 / 1000] average reconstruction error: 2.133077
# Epoch [332 / 1000] average reconstruction error: 2.082308
# Epoch [333 / 1000] average reconstruction error: 2.018628
# Epoch [334 / 1000] average reconstruction error: 2.056005
# Epoch [335 / 1000] average reconstruction error: 1.973587
# Epoch [336 / 1000] average reconstruction error: 1.973977
# Epoch [337 / 1000] average reconstruction error: 1.938213
# Epoch [338 / 1000] average reconstruction error: 1.922388
# Epoch [339 / 1000] average reconstruction error: 1.921894
# Epoch [340 / 1000] average reconstruction error: 1.862880
# Epoch [341 / 1000] average reconstruction error: 1.902599
# Epoch [342 / 1000] average reconstruction error: 1.850911
# Epoch [343 / 1000] average reconstruction error: 1.878075
# Epoch [344 / 1000] average reconstruction error: 1.881189
# Epoch [345 / 1000] average reconstruction error: 1.887891
# Epoch [346 / 1000] average reconstruction error: 1.930200
# Epoch [347 / 1000] average reconstruction error: 1.869597
# Epoch [348 / 1000] average reconstruction error: 1.836393
# Epoch [349 / 1000] average reconstruction error: 1.769843
# Epoch [350 / 1000] average reconstruction error: 1.770953
# Epoch [351 / 1000] average reconstruction error: 1.781706
# Epoch [352 / 1000] average reconstruction error: 1.759289
# Epoch [353 / 1000] average reconstruction error: 1.732021
# Epoch [354 / 1000] average reconstruction error: 1.712822
# Epoch [355 / 1000] average reconstruction error: 1.715423
# Epoch [356 / 1000] average reconstruction error: 1.704967
# Epoch [357 / 1000] average reconstruction error: 1.683252
# Epoch [358 / 1000] average reconstruction error: 1.666079
# Epoch [359 / 1000] average reconstruction error: 1.665607
# Epoch [360 / 1000] average reconstruction error: 1.646084
# Epoch [361 / 1000] average reconstruction error: 1.638375
# Epoch [362 / 1000] average reconstruction error: 1.621018
# Epoch [363 / 1000] average reconstruction error: 1.617941
# Epoch [364 / 1000] average reconstruction error: 1.612134
# Epoch [365 / 1000] average reconstruction error: 1.597981
# Epoch [366 / 1000] average reconstruction error: 1.592663
# Epoch [367 / 1000] average reconstruction error: 1.580255
# Epoch [368 / 1000] average reconstruction error: 1.574865
# Epoch [369 / 1000] average reconstruction error: 1.575499
# Epoch [370 / 1000] average reconstruction error: 1.589334
# Epoch [371 / 1000] average reconstruction error: 1.619404
# Epoch [372 / 1000] average reconstruction error: 1.669216
# Epoch [373 / 1000] average reconstruction error: 1.741743
# Epoch [374 / 1000] average reconstruction error: 1.715541
# Epoch [375 / 1000] average reconstruction error: 1.650142
# Epoch [376 / 1000] average reconstruction error: 1.669157
# Epoch [377 / 1000] average reconstruction error: 1.719338
# Epoch [378 / 1000] average reconstruction error: 1.629526
# Epoch [379 / 1000] average reconstruction error: 1.592545
# Epoch [380 / 1000] average reconstruction error: 1.601633
# Epoch [381 / 1000] average reconstruction error: 1.551628
# Epoch [382 / 1000] average reconstruction error: 1.556224
# Epoch [383 / 1000] average reconstruction error: 1.567159
# Epoch [384 / 1000] average reconstruction error: 1.510530
# Epoch [385 / 1000] average reconstruction error: 1.499772
# Epoch [386 / 1000] average reconstruction error: 1.519777
# Epoch [387 / 1000] average reconstruction error: 1.504249
# Epoch [388 / 1000] average reconstruction error: 1.474595
# Epoch [389 / 1000] average reconstruction error: 1.490911
# Epoch [390 / 1000] average reconstruction error: 1.465770
# Epoch [391 / 1000] average reconstruction error: 1.442948
# Epoch [392 / 1000] average reconstruction error: 1.452157
# Epoch [393 / 1000] average reconstruction error: 1.441679
# Epoch [394 / 1000] average reconstruction error: 1.424894
# Epoch [395 / 1000] average reconstruction error: 1.445487
# Epoch [396 / 1000] average reconstruction error: 1.429350
# Epoch [397 / 1000] average reconstruction error: 1.441903
# Epoch [398 / 1000] average reconstruction error: 1.450410
# Epoch [399 / 1000] average reconstruction error: 1.440578
# Epoch [400 / 1000] average reconstruction error: 1.434785
# Epoch [401 / 1000] average reconstruction error: 1.420261
# Epoch [402 / 1000] average reconstruction error: 1.396708
# Epoch [403 / 1000] average reconstruction error: 1.383866
# Epoch [404 / 1000] average reconstruction error: 1.396368
# Epoch [405 / 1000] average reconstruction error: 1.399786
# Epoch [406 / 1000] average reconstruction error: 1.400106
# Epoch [407 / 1000] average reconstruction error: 1.391399
# Epoch [408 / 1000] average reconstruction error: 1.351588
# Epoch [409 / 1000] average reconstruction error: 1.328887
# Epoch [410 / 1000] average reconstruction error: 1.348675
# Epoch [411 / 1000] average reconstruction error: 1.358778
# Epoch [412 / 1000] average reconstruction error: 1.353592
# Epoch [413 / 1000] average reconstruction error: 1.328578
# Epoch [414 / 1000] average reconstruction error: 1.311268
# Epoch [415 / 1000] average reconstruction error: 1.315709
# Epoch [416 / 1000] average reconstruction error: 1.329344
# Epoch [417 / 1000] average reconstruction error: 1.311906
# Epoch [418 / 1000] average reconstruction error: 1.289977
# Epoch [419 / 1000] average reconstruction error: 1.278633
# Epoch [420 / 1000] average reconstruction error: 1.277795
# Epoch [421 / 1000] average reconstruction error: 1.272959
# Epoch [422 / 1000] average reconstruction error: 1.260933
# Epoch [423 / 1000] average reconstruction error: 1.251627
# Epoch [424 / 1000] average reconstruction error: 1.247269
# Epoch [425 / 1000] average reconstruction error: 1.245176
# Epoch [426 / 1000] average reconstruction error: 1.245852
# Epoch [427 / 1000] average reconstruction error: 1.245902
# Epoch [428 / 1000] average reconstruction error: 1.248883
# Epoch [429 / 1000] average reconstruction error: 1.258593
# Epoch [430 / 1000] average reconstruction error: 1.290590
# Epoch [431 / 1000] average reconstruction error: 1.322280
# Epoch [432 / 1000] average reconstruction error: 1.376687
# Epoch [433 / 1000] average reconstruction error: 1.400208
# Epoch [434 / 1000] average reconstruction error: 1.394993
# Epoch [435 / 1000] average reconstruction error: 1.345701
# Epoch [436 / 1000] average reconstruction error: 1.415611
# Epoch [437 / 1000] average reconstruction error: 1.484224
# Epoch [438 / 1000] average reconstruction error: 1.383358
# Epoch [439 / 1000] average reconstruction error: 1.278136
# Epoch [440 / 1000] average reconstruction error: 1.395993
# Epoch [441 / 1000] average reconstruction error: 1.313954
# Epoch [442 / 1000] average reconstruction error: 1.264803
# Epoch [443 / 1000] average reconstruction error: 1.312771
# Epoch [444 / 1000] average reconstruction error: 1.248942
# Epoch [445 / 1000] average reconstruction error: 1.275215
# Epoch [446 / 1000] average reconstruction error: 1.234055
# Epoch [447 / 1000] average reconstruction error: 1.231831
# Epoch [448 / 1000] average reconstruction error: 1.229602
# Epoch [449 / 1000] average reconstruction error: 1.190467
# Epoch [450 / 1000] average reconstruction error: 1.215394
# Epoch [451 / 1000] average reconstruction error: 1.175013
# Epoch [452 / 1000] average reconstruction error: 1.180507
# Epoch [453 / 1000] average reconstruction error: 1.171561
# Epoch [454 / 1000] average reconstruction error: 1.158210
# Epoch [455 / 1000] average reconstruction error: 1.162921
# Epoch [456 / 1000] average reconstruction error: 1.145230
# Epoch [457 / 1000] average reconstruction error: 1.156812
# Epoch [458 / 1000] average reconstruction error: 1.136600
# Epoch [459 / 1000] average reconstruction error: 1.135124
# Epoch [460 / 1000] average reconstruction error: 1.128032
# Epoch [461 / 1000] average reconstruction error: 1.121268
# Epoch [462 / 1000] average reconstruction error: 1.121155
# Epoch [463 / 1000] average reconstruction error: 1.107969
# Epoch [464 / 1000] average reconstruction error: 1.109237
# Epoch [465 / 1000] average reconstruction error: 1.100939
# Epoch [466 / 1000] average reconstruction error: 1.103544
# Epoch [467 / 1000] average reconstruction error: 1.115534
# Epoch [468 / 1000] average reconstruction error: 1.142064
# Epoch [469 / 1000] average reconstruction error: 1.187442
# Epoch [470 / 1000] average reconstruction error: 1.247407
# Epoch [471 / 1000] average reconstruction error: 1.320399
# Epoch [472 / 1000] average reconstruction error: 1.364038
# Epoch [473 / 1000] average reconstruction error: 1.315558
# Epoch [474 / 1000] average reconstruction error: 1.310660
# Epoch [475 / 1000] average reconstruction error: 1.295076
# Epoch [476 / 1000] average reconstruction error: 1.271674
# Epoch [477 / 1000] average reconstruction error: 1.249338
# Epoch [478 / 1000] average reconstruction error: 1.205051
# Epoch [479 / 1000] average reconstruction error: 1.193166
# Epoch [480 / 1000] average reconstruction error: 1.153731
# Epoch [481 / 1000] average reconstruction error: 1.187504
# Epoch [482 / 1000] average reconstruction error: 1.143732
# Epoch [483 / 1000] average reconstruction error: 1.134911
# Epoch [484 / 1000] average reconstruction error: 1.114611
# Epoch [485 / 1000] average reconstruction error: 1.108740
# Epoch [486 / 1000] average reconstruction error: 1.089792
# Epoch [487 / 1000] average reconstruction error: 1.090057
# Epoch [488 / 1000] average reconstruction error: 1.067796
# Epoch [489 / 1000] average reconstruction error: 1.086864
# Epoch [490 / 1000] average reconstruction error: 1.059908
# Epoch [491 / 1000] average reconstruction error: 1.050702
# Epoch [492 / 1000] average reconstruction error: 1.054334
# Epoch [493 / 1000] average reconstruction error: 1.041559
# Epoch [494 / 1000] average reconstruction error: 1.037884
# Epoch [495 / 1000] average reconstruction error: 1.029828
# Epoch [496 / 1000] average reconstruction error: 1.024441
# Epoch [497 / 1000] average reconstruction error: 1.017819
# Epoch [498 / 1000] average reconstruction error: 1.014096
# Epoch [499 / 1000] average reconstruction error: 1.007954
# Epoch [500 / 1000] average reconstruction error: 1.003900
# Epoch [501 / 1000] average reconstruction error: 0.999550
# Epoch [502 / 1000] average reconstruction error: 0.996015
# Epoch [503 / 1000] average reconstruction error: 0.989500
# Epoch [504 / 1000] average reconstruction error: 0.989536
# Epoch [505 / 1000] average reconstruction error: 0.985792
# Epoch [506 / 1000] average reconstruction error: 0.980882
# Epoch [507 / 1000] average reconstruction error: 0.978265
# Epoch [508 / 1000] average reconstruction error: 0.974818
# Epoch [509 / 1000] average reconstruction error: 0.973383
# Epoch [510 / 1000] average reconstruction error: 0.972248
# Epoch [511 / 1000] average reconstruction error: 0.972106
# Epoch [512 / 1000] average reconstruction error: 0.971423
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-4ef27a05ae82> in <module>
#      11     num_batches = 0
#      12
# ---> 13     for lab_batch, _ in train_dataloader:
#      14
#      15         lab_batch = lab_batch.to(device)
#
# /usr/lib/python3/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     361
#     362     def __next__(self):
# --> 363         data = self._next_data()
#     364         self._num_yielded += 1
#     365         if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/lib/python3/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     972
#     973             assert not self._shutdown and self._tasks_outstanding > 0
# --> 974             idx, data = self._get_data()
#     975             self._tasks_outstanding -= 1
#     976
#
# /usr/lib/python3/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#     929         elif self._pin_memory:
#     930             while self._pin_memory_thread.is_alive():
# --> 931                 success, data = self._try_get_data()
#     932                 if success:
#     933                     return data
#
# /usr/lib/python3/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     777         #   (bool: whether successfully get data, any: data if successful else None)
#     778         try:
# --> 779             data = self._data_queue.get(timeout=timeout)
#     780             return (True, data)
#     781         except Exception as e:
#
# /usr/lib/python3.8/queue.py in get(self, block, timeout)
#     177                     if remaining <= 0.0:
#     178                         raise Empty
# --> 179                     self.not_empty.wait(remaining)
#     180             item = self._get()
#     181             self.not_full.notify()
#
# /usr/lib/python3.8/threading.py in wait(self, timeout)
#     304             else:
#     305                 if timeout > 0:
# --> 306                     gotit = waiter.acquire(True, timeout)
#     307                 else:
#     308                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
